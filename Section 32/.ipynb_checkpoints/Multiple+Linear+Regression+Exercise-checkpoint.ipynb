# %% [markdown]
# # Multiple Linear Regression - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size_year.csv'.
#
# You are expected to create a multiple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables are 'size' and 'year'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm 
from sklearn.linear_model import LinearRegression
import seaborn as sns 

sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv("real_estate_price_size_year.csv")
data.head()
# Out:
#         price     size  year
# 0  234314.144   643.09  2015
# 1  228581.528   656.22  2009
# 2  281626.336   487.29  2018
# 3  401255.608  1504.75  2015
# 4  458674.256  1275.46  2009

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
y = data['price']
x1 = data[["size", "year"]]

# Create the scikit model
model = LinearRegression()
model.fit(x1, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Regression

# %%
# Add constant
x = sm.add_constant(x1)


results = sm.OLS(y, x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Sat, 27 Jul 2024   Prob (F-statistic):           2.77e-32
# Time:                        00:57:45   Log-Likelihood:                -1191.7
# No. Observations:                 100   AIC:                             2389.
# Df Residuals:                      97   BIC:                             2397.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.772e+06   1.58e+06     -3.647      0.000   -8.91e+06   -2.63e+06
# ...

# %%
yhat = 5772000 + 227.7009 * x1 + 2916.7853 * x1
print(yhat)
# Out:
#             size          year
# 0   7.794188e+06  1.210814e+07
# 1   7.835475e+06  1.208927e+07
# 2   7.304277e+06  1.211757e+07
# 3   1.050367e+07  1.210814e+07
# 4   9.782666e+06  1.208927e+07
# ..           ...           ...
# 95  7.500839e+06  1.208927e+07
# 96  9.034216e+06  1.208927e+07
# 97  1.050367e+07  1.207984e+07
# 98  7.810539e+06  1.210814e+07
# 99  7.989775e+06  1.207984e+07
#
# [100 rows x 2 columns]

# %%
# Plot the relationship between Y and X1
plt.scatter(x1["size"], y)
plt.xlabel("Size", fontsize=15)
plt.ylabel("Price", fontsize=15)

# Show the regression line
fig = plt.plot(x1['size'], yhat, lw=4, c="orange", label="regression line")

# Show the plot
plt.show()

plt.scatter(x1["year"], y)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Price", fontsize=15)

# Show the regression line
fig = plt.plot(x1['year'], yhat, lw=4, c="yellow", label="regression line")
plt.show()



# plot.xlabel("
