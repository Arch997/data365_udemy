# %%
"""Identifying Outliers

    Task: Identify players who had unusually high or low performance in any season.
    Steps:
        Use statistical methods to detect outliers in performance metrics (e.g., points per game, assists).
        Investigate the context around these outliers (e.g., injuries, trades) to understand the reasons behind the anomalies."""

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import RobustScaler
from scipy.stats import zscore

sns.set()

# %% [markdown]
# ## Load the data

# %%
raw_data = pd.read_csv("../NBA/nba.csv") 

raw_data.rename(columns={"year": "SEASON", "Season_type": "SEASON_TYPE"}, inplace=True)

raw_data.describe(include="all")
# Out:
#          SEASON       SEASON_TYPE     PLAYER_ID         RANK        PLAYER  \
# count      8835              8835  8.835000e+03  8835.000000          8835
# unique       12                 2           NaN          NaN          1568
# top     2021-22  Regular%20Season           NaN          NaN  James Harden
# freq        822              6259           NaN          NaN            24
# mean        NaN               NaN  7.582528e+05   217.041087           NaN
# std         NaN               NaN  7.201855e+05   150.467367           NaN
# min         NaN               NaN  2.550000e+02     1.000000           NaN
# 25%         NaN               NaN  2.019500e+05    92.000000           NaN
# 50%         NaN               NaN  2.035010e+05   183.000000           NaN
# 75%         NaN               NaN  1.628412e+06   337.500000           NaN
# max         NaN               NaN  1.642013e+06   582.000000           NaN
#
#              TEAM_ID  TEAM           GP          MIN          FGM  ...  \
# count   8.835000e+03  8835  8835.000000  8835.000000  8835.000000  ...
# unique           NaN    31          NaN          NaN          NaN  ...
# top              NaN   BOS          NaN          NaN          NaN  ...
# freq             NaN   359          NaN          NaN          NaN  ...
# mean    1.610613e+09   NaN    36.999434   844.860441   138.528693  ...
# std     8.609213e+00   NaN    28.227778   823.156717   159.765333  ...
# min     1.610613e+09   NaN     1.000000     0.000000     0.000000  ...
# 25%     1.610613e+09   NaN     8.000000   129.000000    16.000000  ...
# 50%     1.610613e+09   NaN    34.000000   526.000000    72.000000  ...
# 75%     1.610613e+09   NaN    65.000000  1477.500000   217.000000  ...
# max     1.610613e+09   NaN    84.000000  3167.000000   857.000000  ...
#
#                 REB          AST          STL          BLK          TOV  \
# count   8835.000000  8835.000000  8835.000000  8835.000000  8835.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     152.578834    82.459989    26.598755    16.975778    47.139898
# std      177.290498   115.606530    29.896816    25.662265    55.854539
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       20.000000     7.000000     3.000000     1.000000     5.000000
# 50%       86.000000    35.000000    15.000000     7.000000    25.000000
# 75%      231.000000   109.000000    42.000000    22.000000    71.000000
# max     1247.000000   907.000000   191.000000   269.000000   464.000000
#
#                  PF          PTS          EFF      AST_TOV      STL_TOV
# count   8835.000000  8835.000000  8835.000000  8835.000000  8835.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      70.188342   374.351896   424.678778     1.582568     0.628661
# std       66.013537   437.467232   478.949440     1.156207     0.556496
# min        0.000000     0.000000    -8.000000     0.000000     0.000000
# 25%       12.000000    42.000000    51.000000     0.900000     0.330000
# 50%       48.000000   191.000000   227.000000     1.460000     0.530000
# 75%      120.000000   580.000000   678.000000     2.110000     0.810000
# max      301.000000  2818.000000  3039.000000    17.000000     8.000000
#
# [11 rows x 30 columns]

# %% [markdown]
# ### Identify performance metrics

# %%
p_metrics = raw_data[["PTS", "AST",  "REB", "STL", "BLK"]]
p_metrics
# Out:
#        PTS  AST  REB  STL  BLK
# 0     2280  374  640  116  105
# 1     2133  469  433  106   25
# 2     2036  551  610  129   67
# 3     2023  455  379  142   38
# 4     1920  171  460   52   32
# ...    ...  ...  ...  ...  ...
# 8830     0    1    3    0    0
# 8831     0    1    1    0    0
# 8832     0    1    3    0    0
# 8833     0    0    0    0    0
# 8834     0    0    0    1    1
#
# [8835 rows x 5 columns]

# %% [markdown]
# #### Calculate basic stats

# %%
p_metrics.mean()
# Out:
# PTS    374.351896
# AST     82.459989
# REB    152.578834
# STL     26.598755
# BLK     16.975778
# dtype: float64

# %%
cols_to_scale = [col for col in p_metrics]
scaled_cols = [f"{col}_Z" for col in p_metrics]

# %% [markdown]
# ### Identify outliers

# %%
# Check for NaNs and drop rows with NaNs in the specified columns
p_metrics = p_metrics.dropna(subset=cols_to_scale)

# Apply zscore to the selected columns, handling NaN values and zero standard deviation
scaled_values = p_metrics[cols_to_scale].apply(lambda x: zscore(x) if x.std() != 0 else x)

# Rename the columns of the scaled_values DataFrame
scaled_values.columns = scaled_cols

p_metrics.loc[:, scaled_cols] = scaled_values

# Define a threshold for outliers. How many standard deviations away from the mean a data point must be to be considered an outlier.
threshold = 3

outliers = p_metrics[(p_metrics["PTS_Z"].abs() > threshold) | (p_metrics["AST_Z"].abs() > threshold) 
    | (p_metrics["REB_Z"].abs() > threshold) | (p_metrics["STL_Z"].abs() > threshold) | (p_metrics["BLK_Z"].abs() > threshold)]
outliers
# Out:
#        PTS  AST  REB  STL  BLK     PTS_Z     AST_Z     REB_Z     STL_Z  \
# 0     2280  374  640  116  105  4.356340  2.521973  2.749435  2.990496
# 1     2133  469  433  106   25  4.020296  3.343772  1.581794  2.655993
# 2     2036  551  610  129   67  3.798552  4.053115  2.580212  3.425349
# 3     2023  455  379  142   38  3.768834  3.222665  1.277192  3.860203
# 4     1920  171  460   52   32  3.533375  0.765917  1.734095  0.849679
# ...    ...  ...  ...  ...  ...       ...       ...       ...       ...
# 8190   790  485  179   71   18  0.950178  3.482180  0.149036  1.485234
# 8196   771  478  289   78    9  0.906743  3.421627  0.769522  1.719386
# 8207   715  247  273  120   70  0.778727  1.423357  0.679269  3.124297
# 8215   663   37  708   73   48  0.659854 -0.393253  3.133008  1.552134
# 8261   518   60  481   30  154  0.328382 -0.194291  1.852551  0.113773
#
#          BLK_Z
# 0     3.430298
# 1     0.312703
# 2     1.949440
# 3     0.819312
# 4     0.585493
# ...        ...
# 8190  0.039914
# 8196 -0.310815
# 8207  2.066350
# 8215  1.209012
# 8261  5.339824
#
# [629 rows x 10 columns]

# %%
# Using IQR 
Q1 = p_metrics[cols_to_scale].quantile(0.25) 
Q3 = p_metrics[cols_to_scale].quantile(0.75)

IQR = Q3 - Q1 

iqr_outliers = p_metrics[((p_metrics[cols_to_scale] < (Q1 - 1.5 * IQR)) | (p_metrics[cols_to_scale] > (Q3 + 1.5 * IQR))).any(axis=1)]

iqr_outliers
# Out:
#        PTS  AST  REB  STL  BLK     PTS_Z     AST_Z     REB_Z     STL_Z  \
# 0     2280  374  640  116  105  4.356340  2.521973  2.749435  2.990496
# 1     2133  469  433  106   25  4.020296  3.343772  1.581794  2.655993
# 2     2036  551  610  129   67  3.798552  4.053115  2.580212  3.425349
# 3     2023  455  379  142   38  3.768834  3.222665  1.277192  3.860203
# 4     1920  171  460   52   32  3.533375  0.765917  1.734095  0.849679
# ...    ...  ...  ...  ...  ...       ...       ...       ...       ...
# 8304   379   63  322   27   61  0.010626 -0.168339  0.955667  0.013422
# 8316   354   90  136  113   49 -0.046525  0.065225 -0.093518  2.890145
# 8323   334   67  261   23   61 -0.092245 -0.133737  0.611580 -0.120379
# 8333   311   79  286   32   72 -0.144823 -0.029931  0.752599  0.180673
# 8360   253   41  238   22   60 -0.277412 -0.358650  0.481842 -0.153830
#
#          BLK_Z
# 0     3.430298
# 1     0.312703
# 2     1.949440
# 3     0.819312
# 4     0.585493
# ...        ...
# 8304  1.715621
# 8316  1.247982
# 8323  1.715621
# 8333  2.144290
# 8360  1.676651
#
# [1452 rows x 10 columns]
